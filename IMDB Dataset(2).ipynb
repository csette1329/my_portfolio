# %% [markdown]
# # Conclusions of Random Forests model applied to IMDB Movie Dataset to predict Average Rating
#
# ## Mean Absolute Error
#
# We obtained a MAE of 0.26, pretty accurate considering a scale of 0-10 for IMBD rating.
#
# ## Features Importance
#
# 1. **Worldwide_Gross**: most important feature to predict movie IMBD rating (makes sense)
#
# 2. **Metascore**: second most important feature to predict movie IMDB rating (makes sense)
#
# 3. **Budget**: least importante feature to predict movie IMBD rating (a bit surprising, perhaps the best rated movies not always had the greatest budgets)
#
# ## Real Values vs Predicted Values
#
# The scatterplot shows that for lowest rating movies, our predictions for IMDB rating were more "optmistic", i.e, we had better predicted IMDB scores than reality. Also, our accuracy was better for predicting IMBD ratings for lower ratings (up to ratings = 7.75). But as we move forward on our x-axis (real values), we can see that our model makes more pessimistic predictions (predicted value is lower than reality) and less accurate.
#
# ## Error Distribution
#
# Our graph shows that 80% of our values had an absolute error of 0.4 or less.
#
# ### Final comments
#
# This model is simple but yet had a decent accuracy for predicting movies IMDB ratings based on the features ['Metascore','Budget','Worldwide_Gross'].

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Read the CSV file into a DataFrame
df = pd.read_csv('IMDB_Movies_Dataset.csv')
df = df.set_index(df.columns[0])
df.index.name = 'Index' 

# Remove spaces from columns names
df.columns = df.columns.str.replace(' ', '_')

# Remover NaNs
df = df.dropna()

# Display the DataFrame
df
# Out:
#                           Title  Average_Rating  \
# Index
# 0      The Shawshank Redemption             9.3
# 2                 The Godfather             9.2
# 7               The Dark Knight             9.0
# 8              Schindler's List             9.0
# 9                  12 Angry Men             9.0
# ...                         ...             ...
# 465                  Powaqqatsi             7.2
# 468                  Irina Palm             7.2
# 475                Chico & Rita             7.2
# 479                Silent Light             7.2
# 487                  The Bubble             7.2
#
#                                              Director  \
# Index
# 0                                      Frank Darabont
# 2                                Francis Ford Coppola
# 7                                   Christopher Nolan
# 8                                    Steven Spielberg
# 9                                        Sidney Lumet
# ...                                               ...
# 465                                    Godfrey Reggio
# 468                                     Sam Garbarski
# 475    Tono Errando, Javier Mariscal, Fernando Trueba
# 479                                   Carlos Reygadas
# 487                                         Eytan Fox
#
#                                                   Writer  Metascore  \
# Index
# 0                           Stephen King, Frank Darabont       82.0
# 2                       Mario Puzo, Francis Ford Coppola      100.0
# 7      Jonathan Nolan, Christopher Nolan, David S. Goyer       84.0
# 8                       Thomas Keneally, Steven Zaillian       95.0
# 9                                          Reginald Rose       97.0
# ...                                                  ...        ...
# 465                         Godfrey Reggio, Ken Richards       57.0
# 468                     Philippe Blasband, Martin Herron       55.0
# 475           Ignacio Martínez de Pisón, Fernando Trueba       76.0
# 479                                      Carlos Reygadas       79.0
# 487              Gal Uchovsky, Eytan Fox, Martin Sherman       61.0
#
#                                                     Cast  \
# Index
# 0      Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 2      Marlon Brando, Al Pacino, James Caan, Diane Ke...
# 7      Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 8      Liam Neeson, Ralph Fiennes, Ben Kingsley, Caro...
# 9      Henry Fonda, Lee J. Cobb, Martin Balsam, John ...
# ...                                                  ...
# 465    Christie Brinkley, David Brinkley, Patrick Dis...
# 468    Marianne Faithfull, Predrag 'Miki' Manojlovic,...
# 475    Eman Xor Oña, Limara Meneses, Mario Guerra, Jo...
# 479    Cornelio Wall, Miriam Toews, Maria Pankratz, P...
# 487    Ohad Knoller, Yousef 'Joe' Sweid, Daniella Wir...
#
#                              Release_Date  \
# Index
# 0                October 14, 1994 (India)
# 2                            1978 (India)
# 7                   July 18, 2008 (India)
# 8               December 15, 1993 (India)
# 9          April 10, 1957 (United States)
# ...                                   ...
# 465           June 2, 1988 (West Germany)
# 468              April 18, 2007 (Belgium)
# 475    November 19, 2010 (United Kingdom)
# 479             October 12, 2007 (Mexico)
# 487                June 29, 2006 (Israel)
#
#                                        Country_of_Origin  \
# Index
# 0                                          United States
# 2                                          United States
# 7                          United States, United Kingdom
# 8                                          United States
# 9                                          United States
# ...                                                  ...
# 465                                        United States
# 468    Belgium, Germany, Luxembourg, United Kingdom, ...
# 475                   Spain, United Kingdom, Isle of Man
# 479                 Mexico, France, Netherlands, Germany
# 487                                               Israel
#
#                                     Languages                    Budget  \
# Index
# 0                                     English   $25,000,000 (estimated)
# 2                     English, Italian, Latin    $6,000,000 (estimated)
# 7                           English, Mandarin  $185,000,000 (estimated)
# 8      English, Hebrew, German, Polish, Latin   $22,000,000 (estimated)
# 9                                     English      $350,000 (estimated)
# ...                                       ...                       ...
# 465                    Hopi, English, Spanish    $2,500,000 (estimated)
# 468                                   English    $4,500,000 (estimated)
# 475                  Spanish, English, French    €9,200,000 (estimated)
# 479      Low German, Spanish, French, English      €980,000 (estimated)
# 487                   Hebrew, Arabic, English    $1,500,000 (estimated)
#
#       Worldwide_Gross             Runtime
# Index
# 0         $29,332,133  2 hours 22 minutes
# 2        $250,342,198  2 hours 55 minutes
# 7      $1,009,053,678  2 hours 32 minutes
# 8        $322,161,245  3 hours 15 minutes
# 9              $2,945   1 hour 36 minutes
# ...               ...                 ...
# 465          $592,592   1 hour 39 minutes
# 468       $10,610,835   1 hour 43 minutes
# 475        $2,347,919   1 hour 34 minutes
# 479          $877,577  2 hours 25 minutes
# 487        $1,029,926   1 hour 57 minutes
#
# [1926 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Title', 'Average_Rating', 'Director', 'Writer', 'Metascore', 'Cast',
#        'Release_Date', 'Country_of_Origin', 'Languages', 'Budget',
#        'Worldwide_Gross', 'Runtime'],
#       dtype='object')

# %%
df_train = df

# %%
# extract numeric values
import re

# Clean and convert 'budget' column
def clean_convert(value):
    # Remove all non-numeric values
    clean_value = re.sub(r'[^0-9]', '', value)
    return clean_value

# Apply function to 'budget' column and convert values to numeric type
df_train['Budget'] = df_train['Budget'].apply(clean_convert)
df_train['Budget'] = pd.to_numeric(df_train['Budget'])

# Verify result
print(df_train['Budget'].head())
# Out:
# Index
# 0     25000000
# 2      6000000
# 7    185000000
# 8     22000000
# 9       350000
# Name: Budget, dtype: int64

# %%
# Apply function to 'Worldwide_Gross' column and convert values to numeric type 
df_train['Worldwide_Gross'] = df_train['Worldwide_Gross'].apply(clean_convert)
df_train['Worldwide_Gross'] = pd.to_numeric(df_train['Worldwide_Gross'])

# Verify result
print(df_train['Worldwide_Gross'].head())
# Out:
# Index
# 0      29332133
# 2     250342198
# 7    1009053678
# 8     322161245
# 9          2945
# Name: Worldwide_Gross, dtype: int64

# %%
# Choose target and features
y = df_train.Average_Rating
features = ['Metascore','Budget','Worldwide_Gross']
X = df_train[features]

# %%
# Divide data into training and validation subsets
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,random_state=0)

# %%
X_train
# Out:
#        Metascore    Budget  Worldwide_Gross
# Index
# 32          78.0   2500000          6568101
# 306         90.0    500000             4410
# 54          83.0   3800000         23701317
# 324         82.0  25000000         82468097
# 27          71.0    250000         12021272
# ...          ...       ...              ...
# 131         80.0  23000000        149660003
# 185         75.0   3500000         24949050
# 364         64.0  80000000        350865342
# 32          63.0  15000000        451183391
# 232         79.0   6000000            90777
#
# [1540 rows x 3 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Apply random forests model
forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(X_train, y_train)

movie_preds = forest_model.predict(X_valid)
print(mean_absolute_error(y_valid, movie_preds))
# Out:
# 0.2644792746113991

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Measuring Features importance
# Defining importances.
importances = forest_model.feature_importances_

# Creating a dataframe with importances
feature_importance_df = pd.DataFrame({'feature': features, 'importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

# Plotting importances
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=feature_importance_df)
plt.title('Features Importance')
plt.show()

# %%
# Scatterplot of predicted values vs validation values
plt.figure(figsize=(10, 6))
plt.scatter(y_valid, movie_preds, alpha=0.3)
plt.plot([y_valid.min(), y_valid.max()], [y_valid.min(), y_valid.max()], 'r--')  # Reference line
plt.xlabel('Validation values')
plt.ylabel('Predicted Values')
plt.title('Real values vs. Predicted Values')
plt.show()

# %%
# Scatterplot of predicted values vs validation values
plt.figure(figsize=(10, 6))
plt.scatter(y_valid, movie_preds, alpha=0.3)
plt.plot([y_valid.min(), y_valid.max()], [y_valid.min(), y_valid.max()], 'r--')  # Reference line
plt.xlabel('Validation values')
plt.ylabel('Predicted Values')
plt.title('Real values vs. Predicted Values')
plt.show()

# %%
# Error distribution
y_pred = movie_preds.copy()
y_test = y_valid.copy()
errors = abs(y_pred - y_test)

plt.figure(figsize=(10, 6))
plt.hist(errors, bins=25, edgecolor='k', alpha=0.7)
plt.xlabel('Absolute Error')
plt.ylabel('Frequency')
plt.title('Error Distribution')
plt.show()

# %%
# Error distribution

import numpy as np
import matplotlib.pyplot as plt

y_pred = movie_preds.copy()
y_test = y_valid.copy()

# Calculate the absolute errors
errors = abs(y_pred - y_test)

# Set up the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot the histogram of errors
counts, bins, patches = ax1.hist(errors, bins=25, edgecolor='k', alpha=0.7)
ax1.set_xlabel('Absolute Error')
ax1.set_ylabel('Frequency')
ax1.set_title('Error Distribution')

# Set up the secondary y-axis
ax2 = ax1.twinx()

# Calculate the cumulative percentage of frequency
cum_counts = np.cumsum(counts)
cum_perc = cum_counts / cum_counts[-1] * 100

# Plot the red line for cumulative percentage
ax2.plot(bins[:-1], cum_perc, 'r-', linewidth=2, label='Cumulative Percentage')
ax2.set_ylabel('Cumulative Percentage (%)')
ax2.legend(loc='upper left')

# Display the plot
plt.show()
